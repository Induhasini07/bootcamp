# %%
list=[]
for i in range(5):
    x=input("enter elements")
    list.append(x)
print("list is :",list)
# Out:
# enter elements J
# enter elements I
# enter elements M
# enter elements I
# enter elements N
# list is : ['J', 'I', 'M', 'I', 'N']

# %%
list=[9,8,7,6,5]
for i in list:
    print(i)
# Out:
# 9
# 8
# 7
# 6
# 5

# %%
list=[92,93,94,95,97]
x=int(input("enter elements to add:"))
list.append(x)
print("updated list:",list)
# Out:
# enter elements to add: 06
# updated list: [92, 93, 94, 95, 97, 6]

# %%
list= [97,95,94,93,92]
index=int(input("enter index :"))
element=input("enter elements:")
list.insert(index,element)
print("updated list:",list)
# Out:
# enter index : 12
# enter elements: 13
# updated list: [97, 95, 94, 93, 92, '13']

# %%
list=[10,20,30,40,50]
index=int(input("enter index to remove:"))
list.pop(index)
list.pop(0)
list.pop(-1)
print("updated list:",list)
# Out:
# enter index to remove: 0
# updated list: [30, 40]

# %%
list=[12,10,2,3,9,11]
element=int(input("enter elements to remove:"))
list.remove(element)
print("updated list:",list)
# Out:
# enter elements to remove: 11
# updated list: [12, 10, 2, 3, 9]

# %%
list=[4,13,9,18,12,30,1]
del list
print("list deleted")
# Out:
# list deleted
