# %%
#merge two dictionaries
d1={'a':10,'b':20,'c':77}
d2={'b':70,'c':89,'d':90}
for key in d2:
    if key in d1:
        d1[key]=d1[key]+d2[key]
else:
    d1[key]=d2[key]
    print(d1)
# Out:
# {'a': 10, 'b': 90, 'c': 166, 'd': 90}

# %%
#find key with maximum value
d=d = {'a': 10, 'b': 20, 'c': 20}

max_value = max(d.values())

for key in d:
    if d[key] == max_value:
        print(key)
