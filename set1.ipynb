# %%
x=[23,54,77,87,90,67,44,33,2,13]
print(x)
# Out:
# [23, 54, 77, 87, 90, 67, 44, 33, 2, 13]

# %%
#find maximum 
max=x[0]
for i in x:
    if i>max:
        max=i
print(f"the maximum is {max}")
# Out:
# the maximum is 90
